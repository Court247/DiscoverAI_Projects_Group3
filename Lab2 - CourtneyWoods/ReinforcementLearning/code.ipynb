# %% [markdown]
# # **Custom Environment for Reinforcement Learning**

# %% [markdown]
# The code below is taken from Nicholas Renotte's tutorial on how to create Custom environments for reinforcement learning. [Tutorial](https://youtu.be/Mut_u40Sqz4?t=8940), [code on github](https://github.com/nicknochnack/ReinforcementLearningCourse/blob/main/Project%203%20-%20Custom%20Environment.ipynb).
#
# You are encouraged to visit the links above and check out the full code. In this lab, you will practice training a model.

# %% [markdown]
# **About the problem**

# %% [markdown]
# The task is to build an agent that regulates the shower temperature to give the best shower possible every time.
#
# Based the activity of other people in the building, the temperature fluctuates randomly. Assuming that our optimal temperature is between 37 and 39 degrees, we want to train an agent to automatically respond to changes in temperature and get it back within the preferred range.
#
# Note that the agent does not know the preffered range ahead of time, and should instead learn the types of adjustments it can make to get a reward.

# %% [markdown]
# **Import libraries**

# %%
import os
# Avoid reinstalling packages that are available on edstem
if not os.getenv("ED_COURSE_ID"):
    # !pip install tensorflow stable_baselines3 torch collections gym box2d-py --user

# Import gym libraries
import gym 
from gym import Env # the supperclass to build our own environment
# All different types of spaces available in Gym
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 

# Import helpers
import numpy as np
import random

#Import stable bbaselines libraries
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # Inspect types of spaces

# %% [markdown]
# There are four key types of Gym spaces:
# Box, Discrete, Multibinary and MultiDiscrete.
#
# There are two wrapper spaces, Tuple and Dict that help group different spaces together.
#
# These spaces can be used to create simple environment, like the shower environment in the following example.

# %%
# Define a discrete space
disc = Discrete(3)

# %%
# Sample the discrete space for a value (between 0 and 2)
disc.sample()
# Out:
# 2

# %%
# Define a box space
box = Box(0,1,shape=(3,3))

# %%
#TODO: Sample the box space for a value
box.sample()
# Out:
# array([[0.6122747 , 0.18909328, 0.6312309 ],
#        [0.84964305, 0.10943457, 0.1204793 ],
#        [0.64398813, 0.21332546, 0.65433276]], dtype=float32)

# %%
# Define a tuple space and combine a discrete and box spaces
tup = Tuple((Discrete(2), Box(0,100, shape=(1,))))

# %%
#TODO: Sample the tuple space for a value
tup.sample()
# Out:
# (0, array([47.13248], dtype=float32))

# %%
# Define a dict space
dic = Dict({'height':Discrete(2), "speed":Box(0,100, shape=(1,))}).sample()

# %%
# Define a multibinary space
multibi = MultiBinary(4)

# %%
#TODO: Sample the multibinary space for a value
multibi.sample()
# Out:
# array([1, 1, 0, 1], dtype=int8)

# %%
# Define a multidiscrete space
multidi = MultiDiscrete([5,2,2])

# %%
#TODO: Sample the multidiscrete space for a value
multidi.sample()
# Out:
# array([1, 0, 0])

# %% [markdown]
# # Create a custom environment

# %%
# Define a shower environment class with four key functions
class ShowerEnv(Env):
    # Define a function to initialize the environment
    def __init__(self):
        # Define the discrete action space: 
        # Actions we can take, down, hold, up
        self.action_space = Discrete(3)
        # Define a temperature range from 0 to 100
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
        # Set initial state: starting temp is 38 +- 3
        self.state = 38 + random.randint(-3,3)
        # Set shower length: set to 60 seconds for testing
        self.shower_length = 60

    # Define the step function for what to do in one action step    
    def step(self, action):
        # Apply impact of the action on current state
        # 0 -1 = -1 temperature
        # 1 -1 = 0 
        # 2 -1 = 1 temperature 
        self.state += action -1 
        # Reduce shower length by 1 second at each action
        self.shower_length -= 1 
        
        # Calculate reward
        # If the temperature is within preferred range, the reward is positive
        if self.state >= 37 and self.state <= 39: 
            reward = 1 
        # If the reward is outside of preferred range, the reward is negative 
        else: 
            reward = -1 
        
        # Check if shower is done
        if self.shower_length <= 0: 
            done = True
        else:
            done = False
        
        # Set placeholder for info
        info = {}
        
        # Return step information
        return self.state, reward, done, info

    # For this lab, we will not implement a visualization of the environment
    def render(self):
        # Implement viz
        pass
    
    # Define function to reset the environment for the next run
    def reset(self):
        # Reset shower temperature to a random value between 35 and 41
        self.state = np.array([38 + random.randint(-3,3)]).astype(float)
        # Reset shower time
        self.shower_length = 60 
        return self.state

# %% [markdown]
# # Test the environment

# %%
# Initialize the environment
env=ShowerEnv()
# Out:
# /usr/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
#TODO: Write code to sample the environment's observation space
env.observation_space.sample()
# Out:
# array([38.46615], dtype=float32)

# %%
#TODO: Write code to sample the environment's action space
env.action_space.sample()
# Out:
# 1

# %%
# Reset the environment
env.reset()
# Out:
# array([37.])

# %%
# Test five episodes of taking random Actions
# in the environment
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
    
env.close()
# Out:
# Episode:1 Score:-56
# Episode:2 Score:-16
# Episode:3 Score:-46
# Episode:4 Score:-18
# Episode:5 Score:-58

# %% [markdown]
# # Earn Your Wings

# %% [markdown]
# Implement the rest of the reinforcement learning algorithm to train the model using MlpPolicy. Save the training in the log_path defined below, and evaluate the model at the end with render set to False. Add comments in your code to explain each step that you take in your implementation.

# %%
# Define a path for where to output the training log files
log_path = os.path.join('ReinforcementLearning/ShowerEnvironment/Training', 'Logs')

# %%
#train the model
model = PPO("MlpPolicy", env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
#initialize the model training
model.learn(total_timesteps=400000)
# Out:
# Logging to ReinforcementLearning/ShowerEnvironment/Training/Logs/PPO_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | -27.5    |
# | time/              |          |
# |    fps             | 3787     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -30.5      |
# | time/                   |            |
# |    fps                  | 2699       |
# |    iterations           | 2          |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00832092 |
# |    clip_fraction        | 0.0541     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | 3.65e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 19.3       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0051    |
# |    value_loss           | 46.1       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -30.4        |
# | time/                   |              |
# |    fps                  | 2449         |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0061496845 |
# |    clip_fraction        | 0.0384       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -6.13e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.7         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00134     |
# |    value_loss           | 52.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -26.5       |
# | time/                   |             |
# |    fps                  | 2341        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010343043 |
# |    clip_fraction        | 0.0322      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000162   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00397    |
# |    value_loss           | 69.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -24.6       |
# | time/                   |             |
# |    fps                  | 2287        |
# |    iterations           | 5           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012909211 |
# |    clip_fraction        | 0.0409      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.000281   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00242    |
# |    value_loss           | 70.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -23.5       |
# | time/                   |             |
# |    fps                  | 2250        |
# |    iterations           | 6           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014188243 |
# |    clip_fraction        | 0.0972      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 5.25e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43          |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00583    |
# |    value_loss           | 65.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -26.5       |
# | time/                   |             |
# |    fps                  | 2229        |
# |    iterations           | 7           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008921052 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 4.86e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.6        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 79.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -25.2        |
# | time/                   |              |
# |    fps                  | 2209         |
# |    iterations           | 8            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0064022196 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.000257    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.5         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00245     |
# |    value_loss           | 77           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -28         |
# | time/                   |             |
# |    fps                  | 2193        |
# |    iterations           | 9           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009610936 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.00025    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42          |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00816    |
# |    value_loss           | 71.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -29.3       |
# | time/                   |             |
# |    fps                  | 2183        |
# |    iterations           | 10          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.006131158 |
# |    clip_fraction        | 0.0606      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.000259   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.7        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00363    |
# |    value_loss           | 69.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -29.7       |
# | time/                   |             |
# |    fps                  | 2176        |
# |    iterations           | 11          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014588543 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -1.57e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.4        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00319    |
# |    value_loss           | 76.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -25.6      |
# | time/                   |            |
# |    fps                  | 2171       |
# |    iterations           | 12         |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00350797 |
# |    clip_fraction        | 0.0354     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | -0.000102  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 35.5       |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00193   |
# |    value_loss           | 76.9       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -22.1        |
# | time/                   |              |
# |    fps                  | 2166         |
# |    iterations           | 13           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0046449574 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.974       |
# |    explained_variance   | 0.000326     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46.9         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00252     |
# |    value_loss           | 88.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -18.5        |
# | time/                   |              |
# |    fps                  | 2162         |
# |    iterations           | 14           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0027253283 |
# |    clip_fraction        | 0.0524       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.958       |
# |    explained_variance   | 0.000899     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.2         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00292     |
# |    value_loss           | 91.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -12          |
# | time/                   |              |
# |    fps                  | 2148         |
# |    iterations           | 15           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0061118053 |
# |    clip_fraction        | 0.0947       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.928       |
# |    explained_variance   | -0.00222     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.7         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00703     |
# |    value_loss           | 80           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -9.7        |
# | time/                   |             |
# |    fps                  | 2145        |
# |    iterations           | 16          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.004637819 |
# |    clip_fraction        | 0.0519      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.897      |
# |    explained_variance   | 0.00049     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.1        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00259    |
# |    value_loss           | 62.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -9.56       |
# | time/                   |             |
# |    fps                  | 2143        |
# |    iterations           | 17          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.006120358 |
# |    clip_fraction        | 0.0747      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.86       |
# |    explained_variance   | -0.00175    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.8        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00225    |
# |    value_loss           | 76.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -8.94       |
# | time/                   |             |
# |    fps                  | 2141        |
# |    iterations           | 18          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006262837 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.876      |
# |    explained_variance   | -0.00417    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37          |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00819    |
# |    value_loss           | 82.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -13.9       |
# | time/                   |             |
# |    fps                  | 2138        |
# |    iterations           | 19          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006050219 |
# |    clip_fraction        | 0.0881      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | -0.0126     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.4        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00466    |
# |    value_loss           | 64.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -9.32        |
# | time/                   |              |
# |    fps                  | 2135         |
# |    iterations           | 20           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0059988527 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.904       |
# |    explained_variance   | 0.00116      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.7         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.01        |
# |    value_loss           | 54           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -7.92       |
# | time/                   |             |
# |    fps                  | 2128        |
# |    iterations           | 21          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004791017 |
# |    clip_fraction        | 0.0718      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.88       |
# |    explained_variance   | 0.00405     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.9        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00257    |
# |    value_loss           | 70.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -0.44       |
# | time/                   |             |
# |    fps                  | 2118        |
# |    iterations           | 22          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004752474 |
# |    clip_fraction        | 0.0878      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.857      |
# |    explained_variance   | 0.0107      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.5        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00712    |
# |    value_loss           | 62.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -3.9        |
# | time/                   |             |
# |    fps                  | 2115        |
# |    iterations           | 23          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006327967 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.861      |
# |    explained_variance   | 0.0246      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.6        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00347    |
# |    value_loss           | 65.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 0.02        |
# | time/                   |             |
# |    fps                  | 2115        |
# |    iterations           | 24          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008077719 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.854      |
# |    explained_variance   | 0.0642      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.4        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 76.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -2.74        |
# | time/                   |              |
# |    fps                  | 2113         |
# |    iterations           | 25           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0065493584 |
# |    clip_fraction        | 0.0739       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.818       |
# |    explained_variance   | -0.0558      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.9         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00162     |
# |    value_loss           | 65.3         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 1.24       |
# | time/                   |            |
# |    fps                  | 2113       |
# |    iterations           | 26         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.00838455 |
# |    clip_fraction        | 0.121      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.798     |
# |    explained_variance   | -0.00448   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 39.8       |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.00394   |
# |    value_loss           | 85.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -0.44       |
# | time/                   |             |
# |    fps                  | 2113        |
# |    iterations           | 27          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008393433 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.802      |
# |    explained_variance   | -0.00564    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.1        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 68.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 7.38         |
# | time/                   |              |
# |    fps                  | 2108         |
# |    iterations           | 28           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0094033815 |
# |    clip_fraction        | 0.0837       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.818       |
# |    explained_variance   | -0.0271      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.5         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00454     |
# |    value_loss           | 56           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 10.5         |
# | time/                   |              |
# |    fps                  | 2105         |
# |    iterations           | 29           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0067766486 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.853       |
# |    explained_variance   | 0.00126      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.7         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00644     |
# |    value_loss           | 45.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 17.3         |
# | time/                   |              |
# |    fps                  | 2103         |
# |    iterations           | 30           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0073725805 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.834       |
# |    explained_variance   | -0.0447      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.3         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00849     |
# |    value_loss           | 66.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 21.3         |
# | time/                   |              |
# |    fps                  | 2100         |
# |    iterations           | 31           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0070644394 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.846       |
# |    explained_variance   | 0.000883     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.9         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00882     |
# |    value_loss           | 45.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 24.5        |
# | time/                   |             |
# |    fps                  | 2099        |
# |    iterations           | 32          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.015950687 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.833      |
# |    explained_variance   | -0.000142   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.3        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00704    |
# |    value_loss           | 54.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 27.8        |
# | time/                   |             |
# |    fps                  | 2100        |
# |    iterations           | 33          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.007300521 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.811      |
# |    explained_variance   | 0.00624     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.2        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 54.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 32          |
# | time/                   |             |
# |    fps                  | 2100        |
# |    iterations           | 34          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006331752 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.802      |
# |    explained_variance   | 0.0213      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.1        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00233    |
# |    value_loss           | 53.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 35.8         |
# | time/                   |              |
# |    fps                  | 2099         |
# |    iterations           | 35           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0035888702 |
# |    clip_fraction        | 0.0947       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.812       |
# |    explained_variance   | 0.0124       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.2         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00312     |
# |    value_loss           | 51.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 32.2        |
# | time/                   |             |
# |    fps                  | 2097        |
# |    iterations           | 36          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.012773773 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.812      |
# |    explained_variance   | -0.00188    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.8        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00784     |
# |    value_loss           | 54.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 35          |
# | time/                   |             |
# |    fps                  | 2095        |
# |    iterations           | 37          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.013619177 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.823      |
# |    explained_variance   | -0.000975   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.5        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 84          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 36.9         |
# | time/                   |              |
# |    fps                  | 2096         |
# |    iterations           | 38           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0074126106 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.836       |
# |    explained_variance   | -3.66e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.4         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.00194      |
# |    value_loss           | 62.2         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 43.3       |
# | time/                   |            |
# |    fps                  | 2096       |
# |    iterations           | 39         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.01417811 |
# |    clip_fraction        | 0.157      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.824     |
# |    explained_variance   | 2.77e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 30.9       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.00843    |
# |    value_loss           | 69.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.1        |
# | time/                   |             |
# |    fps                  | 2096        |
# |    iterations           | 40          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.007709084 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.82       |
# |    explained_variance   | -1.18e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.6        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00683     |
# |    value_loss           | 66.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 46.7         |
# | time/                   |              |
# |    fps                  | 2095         |
# |    iterations           | 41           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0063095866 |
# |    clip_fraction        | 0.137        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.821       |
# |    explained_variance   | -4.11e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41           |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.00475      |
# |    value_loss           | 77.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 46          |
# | time/                   |             |
# |    fps                  | 2095        |
# |    iterations           | 42          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.009149092 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.822      |
# |    explained_variance   | -6.08e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.4        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.0101      |
# |    value_loss           | 83.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 46.7         |
# | time/                   |              |
# |    fps                  | 2095         |
# |    iterations           | 43           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0072137783 |
# |    clip_fraction        | 0.144        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.786       |
# |    explained_variance   | 3.93e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.4         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000583    |
# |    value_loss           | 84.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.7        |
# | time/                   |             |
# |    fps                  | 2096        |
# |    iterations           | 44          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012058072 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.798      |
# |    explained_variance   | 2.28e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.9        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00818     |
# |    value_loss           | 82.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 48.1         |
# | time/                   |              |
# |    fps                  | 2096         |
# |    iterations           | 45           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0061592935 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.787       |
# |    explained_variance   | 2.57e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.3         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.000431     |
# |    value_loss           | 86.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.4        |
# | time/                   |             |
# |    fps                  | 2095        |
# |    iterations           | 46          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.007971138 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 2.59e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50          |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00678     |
# |    value_loss           | 89.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.6        |
# | time/                   |             |
# |    fps                  | 2091        |
# |    iterations           | 47          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.020616643 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.755      |
# |    explained_variance   | 2.65e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.1        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.005       |
# |    value_loss           | 86          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.1        |
# | time/                   |             |
# |    fps                  | 2091        |
# |    iterations           | 48          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.012202877 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.761      |
# |    explained_variance   | 6.4e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.5        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00176    |
# |    value_loss           | 88          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 43.4       |
# | time/                   |            |
# |    fps                  | 2091       |
# |    iterations           | 49         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.01373944 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.741     |
# |    explained_variance   | 0.00962    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 36         |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.00127   |
# |    value_loss           | 83.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 49.7       |
# | time/                   |            |
# |    fps                  | 2091       |
# |    iterations           | 50         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.01901109 |
# |    clip_fraction        | 0.146      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.737     |
# |    explained_variance   | -0.00128   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 40.6       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | 0.0116     |
# |    value_loss           | 79.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 52.5        |
# | time/                   |             |
# |    fps                  | 2092        |
# |    iterations           | 51          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.014474855 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.732      |
# |    explained_variance   | -0.000195   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.8        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.011       |
# |    value_loss           | 85.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 52.2        |
# | time/                   |             |
# |    fps                  | 2091        |
# |    iterations           | 52          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.020336784 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | -3.87e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.7        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00791     |
# |    value_loss           | 90.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 51.7       |
# | time/                   |            |
# |    fps                  | 2090       |
# |    iterations           | 53         |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.00957804 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.712     |
# |    explained_variance   | -2.09e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 45.3       |
# |    n_updates            | 520        |
# |    policy_gradient_loss | 0.00453    |
# |    value_loss           | 96.6       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 52.5         |
# | time/                   |              |
# |    fps                  | 2089         |
# |    iterations           | 54           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0076011866 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.704       |
# |    explained_variance   | -2.12e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.1         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | 0.00741      |
# |    value_loss           | 105          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53.3        |
# | time/                   |             |
# |    fps                  | 2087        |
# |    iterations           | 55          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.005405545 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.731      |
# |    explained_variance   | 1.22e-05    |
# ...
# |    entropy_loss         | -0.277     |
# |    explained_variance   | -0.0385    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 84.9       |
# |    n_updates            | 950        |
# |    policy_gradient_loss | -0.00477   |
# |    value_loss           | 168        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 27.9        |
# | time/                   |             |
# |    fps                  | 2080        |
# |    iterations           | 97          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.015860923 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.181      |
# |    explained_variance   | -0.00101    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76          |
# |    n_updates            | 960         |
# |    policy_gradient_loss | 0.00139     |
# |    value_loss           | 156         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 30.4       |
# | time/                   |            |
# |    fps                  | 2080       |
# |    iterations           | 98         |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 200704     |
# | train/                  |            |
# |    approx_kl            | 0.06431722 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.244     |
# |    explained_variance   | 0.146      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 59.2       |
# |    n_updates            | 970        |
# |    policy_gradient_loss | -0.0253    |
# |    value_loss           | 111        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 30          |
# | time/                   |             |
# |    fps                  | 2080        |
# |    iterations           | 99          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 202752      |
# | train/                  |             |
# |    approx_kl            | 0.051688105 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.238      |
# |    explained_variance   | -0.186      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.2        |
# |    n_updates            | 980         |
# |    policy_gradient_loss | 0.00408     |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 36.6        |
# | time/                   |             |
# |    fps                  | 2080        |
# |    iterations           | 100         |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.031855922 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.19       |
# |    explained_variance   | -0.00226    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 67.3        |
# |    n_updates            | 990         |
# |    policy_gradient_loss | 0.00097     |
# |    value_loss           | 132         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 42.7         |
# | time/                   |              |
# |    fps                  | 2080         |
# |    iterations           | 101          |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 206848       |
# | train/                  |              |
# |    approx_kl            | 0.0023191879 |
# |    clip_fraction        | 0.0409       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.181       |
# |    explained_variance   | 0.00922      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.4         |
# |    n_updates            | 1000         |
# |    policy_gradient_loss | 0.00755      |
# |    value_loss           | 59.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.8        |
# | time/                   |             |
# |    fps                  | 2081        |
# |    iterations           | 102         |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 208896      |
# | train/                  |             |
# |    approx_kl            | 0.013157298 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.191      |
# |    explained_variance   | -0.00783    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.4        |
# |    n_updates            | 1010        |
# |    policy_gradient_loss | 0.0125      |
# |    value_loss           | 78          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 49.1       |
# | time/                   |            |
# |    fps                  | 2080       |
# |    iterations           | 103        |
# |    time_elapsed         | 101        |
# |    total_timesteps      | 210944     |
# | train/                  |            |
# |    approx_kl            | 0.07964365 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.27      |
# |    explained_variance   | -1.28e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 44.3       |
# |    n_updates            | 1020       |
# |    policy_gradient_loss | 0.0131     |
# |    value_loss           | 93.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 45.3       |
# | time/                   |            |
# |    fps                  | 2080       |
# |    iterations           | 104        |
# |    time_elapsed         | 102        |
# |    total_timesteps      | 212992     |
# | train/                  |            |
# |    approx_kl            | 0.00925955 |
# |    clip_fraction        | 0.0508     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.236     |
# |    explained_variance   | 0.0253     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 57.6       |
# |    n_updates            | 1030       |
# |    policy_gradient_loss | 0.00163    |
# |    value_loss           | 94         |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 47         |
# | time/                   |            |
# |    fps                  | 2079       |
# |    iterations           | 105        |
# |    time_elapsed         | 103        |
# |    total_timesteps      | 215040     |
# | train/                  |            |
# |    approx_kl            | 0.08848418 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.293     |
# |    explained_variance   | 0.0624     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 64.6       |
# |    n_updates            | 1040       |
# |    policy_gradient_loss | -0.00725   |
# |    value_loss           | 117        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 48         |
# | time/                   |            |
# |    fps                  | 2079       |
# |    iterations           | 106        |
# |    time_elapsed         | 104        |
# |    total_timesteps      | 217088     |
# | train/                  |            |
# |    approx_kl            | 0.00391602 |
# |    clip_fraction        | 0.0315     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.222     |
# |    explained_variance   | 0.000694   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 55.6       |
# |    n_updates            | 1050       |
# |    policy_gradient_loss | 0.0039     |
# |    value_loss           | 91.9       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 52.1         |
# | time/                   |              |
# |    fps                  | 2079         |
# |    iterations           | 107          |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 219136       |
# | train/                  |              |
# |    approx_kl            | 0.0072465744 |
# |    clip_fraction        | 0.0598       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.232       |
# |    explained_variance   | 0.00109      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 54.5         |
# |    n_updates            | 1060         |
# |    policy_gradient_loss | 0.0118       |
# |    value_loss           | 99           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 52.5         |
# | time/                   |              |
# |    fps                  | 2080         |
# |    iterations           | 108          |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 221184       |
# | train/                  |              |
# |    approx_kl            | 0.0064534815 |
# |    clip_fraction        | 0.0587       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.246       |
# |    explained_variance   | -0.0019      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.5         |
# |    n_updates            | 1070         |
# |    policy_gradient_loss | 0.011        |
# |    value_loss           | 97.8         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 49.3       |
# | time/                   |            |
# |    fps                  | 2080       |
# |    iterations           | 109        |
# |    time_elapsed         | 107        |
# |    total_timesteps      | 223232     |
# | train/                  |            |
# |    approx_kl            | 0.01104036 |
# |    clip_fraction        | 0.0561     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.234     |
# |    explained_variance   | 4.2e-05    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 65.2       |
# |    n_updates            | 1080       |
# |    policy_gradient_loss | 0.00974    |
# |    value_loss           | 104        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.3        |
# | time/                   |             |
# |    fps                  | 2080        |
# |    iterations           | 110         |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 225280      |
# | train/                  |             |
# |    approx_kl            | 0.013542566 |
# |    clip_fraction        | 0.0557      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.226      |
# |    explained_variance   | 0.00319     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64          |
# |    n_updates            | 1090        |
# |    policy_gradient_loss | 0.00605     |
# |    value_loss           | 114         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.1        |
# | time/                   |             |
# |    fps                  | 2079        |
# |    iterations           | 111         |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 227328      |
# | train/                  |             |
# |    approx_kl            | 0.008840245 |
# |    clip_fraction        | 0.0598      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.211      |
# |    explained_variance   | 0.0217      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.8        |
# |    n_updates            | 1100        |
# |    policy_gradient_loss | 0.0114      |
# |    value_loss           | 104         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 44.1       |
# | time/                   |            |
# |    fps                  | 2079       |
# |    iterations           | 112        |
# |    time_elapsed         | 110        |
# |    total_timesteps      | 229376     |
# | train/                  |            |
# |    approx_kl            | 0.08471629 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.254     |
# |    explained_variance   | 0.0888     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 70.8       |
# |    n_updates            | 1110       |
# |    policy_gradient_loss | -0.00976   |
# |    value_loss           | 128        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 41.1         |
# | time/                   |              |
# |    fps                  | 2079         |
# |    iterations           | 113          |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 231424       |
# | train/                  |              |
# |    approx_kl            | 0.0043204455 |
# |    clip_fraction        | 0.0397       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.203       |
# |    explained_variance   | 0.159        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.2         |
# |    n_updates            | 1120         |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 81.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 46.3        |
# | time/                   |             |
# |    fps                  | 2079        |
# |    iterations           | 114         |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 233472      |
# | train/                  |             |
# |    approx_kl            | 0.030164475 |
# |    clip_fraction        | 0.0489      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.207      |
# |    explained_variance   | 0.123       |
# |    learning_rate        | 0.0003      |
# |    lo
# [too much output ...]

# %%
#save model
model.save('PPO')
